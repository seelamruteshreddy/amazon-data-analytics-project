# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('c:/data/amazon_products_sales_data_cleaned (1).csv')
df.head(2)
# Out:
#                                        product_title  product_rating  \
# 0  BOYA BOYALINK 2 Wireless Lavalier Microphone f...             4.6
# 1  LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...             4.3
#
#    total_reviews  purchased_last_month  discounted_price  original_price  \
# 0          375.0                 300.0             89.68          159.00
# 1         2457.0                6000.0              9.99           15.99
#
#   is_best_seller is_sponsored             has_coupon buy_box_availability  \
# 0       No Badge    Sponsored  Save 15%  with coupon          Add to cart
# 1       No Badge    Sponsored              No Coupon          Add to cart
#
#   delivery_date sustainability_tags  \
# 0    2025-09-01       Carbon impact
# 1    2025-08-29                 NaN
#
#                                    product_image_url  \
# 0  https://m.media-amazon.com/images/I/71pAqiVEs3...
# 1  https://m.media-amazon.com/images/I/61nbF6aVIP...
#
#                                     product_page_url    data_collected_at  \
# 0  https://www.amazon.com/sspa/click?ie=UTF8&spc=...  2025-08-21 11:14:29
# 1  https://www.amazon.com/sspa/click?ie=UTF8&spc=...  2025-08-21 11:14:29
#
#   product_category  discount_percentage
# 0           Phones                43.60
# 1          Laptops                37.52

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   product_title         42675 non-null  object
#  1   product_rating        41651 non-null  float64
#  2   total_reviews         41651 non-null  float64
#  3   purchased_last_month  32164 non-null  float64
#  4   discounted_price      40613 non-null  float64
#  5   original_price        40613 non-null  float64
#  6   is_best_seller        42675 non-null  object
#  7   is_sponsored          42675 non-null  object
#  8   has_coupon            42675 non-null  object
#  9   buy_box_availability  28022 non-null  object
#  10  delivery_date         30692 non-null  object
#  11  sustainability_tags   3408 non-null   object
#  12  product_image_url     42675 non-null  object
#  13  product_page_url      40606 non-null  object
#  14  data_collected_at     42675 non-null  object
#  15  product_category      42675 non-null  object
#  16  discount_percentage   40613 non-null  float64
# dtypes: float64(6), object(11)
# memory usage: 5.5+ MB

# %%
df.describe()
# Out:
#        product_rating  total_reviews  purchased_last_month  discounted_price  \
# count    41651.000000   41651.000000          32164.000000      40613.000000
# mean         4.399431    3087.106000           1293.665278        243.227289
# std          0.386997   13030.460133           6318.323574        473.351545
# min          1.000000       1.000000             50.000000          2.160000
# 25%          4.200000      82.000000            100.000000         29.690000
# 50%          4.500000     343.000000            200.000000         84.990000
# 75%          4.700000    1886.000000            400.000000        224.000000
# max          5.000000  865598.000000         100000.000000       5449.000000
#
#        original_price  discount_percentage
# count    40613.000000         40613.000000
# mean       257.611107             6.547151
# std        496.633495            12.744715
# min          2.160000             0.000000
# 25%         32.990000             0.000000
# 50%         89.000000             0.000000
# 75%        229.990000             8.490000
# max       5449.000000            85.420000

# %%
len(df)
# Out:
# 42675

# %%
df.isnull().sum()*100/len(df)
# Out:
# product_title            0.000000
# product_rating           2.399531
# total_reviews            2.399531
# purchased_last_month    24.630346
# discounted_price         4.831869
# original_price           4.831869
# is_best_seller           0.000000
# is_sponsored             0.000000
# has_coupon               0.000000
# buy_box_availability    34.336262
# delivery_date           28.079672
# sustainability_tags     92.014060
# product_image_url        0.000000
# product_page_url         4.848272
# data_collected_at        0.000000
# product_category         0.000000
# discount_percentage      4.831869
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Action Items

# %%
df.columns
# Out:
# Index(['product_title', 'product_rating', 'total_reviews',
#        'purchased_last_month', 'discounted_price', 'original_price',
#        'is_best_seller', 'is_sponsored', 'has_coupon', 'buy_box_availability',
#        'delivery_date', 'sustainability_tags', 'product_image_url',
#        'product_page_url', 'data_collected_at', 'product_category',
#        'discount_percentage'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                         count         mean           std    min     25%  \
# product_rating        41651.0     4.399431      0.386997   1.00    4.20
# total_reviews         41651.0  3087.106000  13030.460133   1.00   82.00
# purchased_last_month  32164.0  1293.665278   6318.323574  50.00  100.00
# discounted_price      40613.0   243.227289    473.351545   2.16   29.69
# original_price        40613.0   257.611107    496.633495   2.16   32.99
# discount_percentage   40613.0     6.547151     12.744715   0.00    0.00
#
#                          50%      75%        max
# product_rating          4.50     4.70       5.00
# total_reviews         343.00  1886.00  865598.00
# purchased_last_month  200.00   400.00  100000.00
# discounted_price       84.99   224.00    5449.00
# original_price         89.00   229.99    5449.00
# discount_percentage     0.00     8.49      85.42

# %%
 num_df=df.select_dtypes(include='number')
cat_df=df.select_dtypes(exclude='number')

# %%
cat_df
# Out:
#                                            product_title is_best_seller  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...       No Badge
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...       No Badge
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...       No Badge
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...    Best Seller
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...       No Badge
# ...                                                  ...            ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...       No Badge
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...       No Badge
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...       Save 18%
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...       No Badge
# 42674  Lorex Fusion 1080p HD Security Camera System w...       No Badge
#
#       is_sponsored                has_coupon buy_box_availability  \
# 0        Sponsored     Save 15%  with coupon          Add to cart
# 1        Sponsored                 No Coupon          Add to cart
# 2        Sponsored                 No Coupon          Add to cart
# 3          Organic                 No Coupon                  NaN
# 4          Organic                 No Coupon                  NaN
# ...            ...                       ...                  ...
# 42670      Organic                 No Coupon                  NaN
# 42671      Organic  Save $25.00  with coupon          Add to cart
# 42672      Organic                 No Coupon          Add to cart
# 42673      Organic                 No Coupon          Add to cart
# 42674      Organic                 No Coupon          Add to cart
#
#       delivery_date sustainability_tags  \
# 0        2025-09-01       Carbon impact
# 1        2025-08-29                 NaN
# 2        2025-09-01                 NaN
# 3               NaN                 NaN
# 4               NaN                 NaN
# ...             ...                 ...
# 42670    2025-09-04                 NaN
# 42671    2025-09-04                 NaN
# 42672    2025-09-04                 NaN
# 42673    2025-09-04                 NaN
# 42674    2025-09-04                 NaN
#
#                                        product_image_url  \
# 0      https://m.media-amazon.com/images/I/71pAqiVEs3...
# 1      https://m.media-amazon.com/images/I/61nbF6aVIP...
# 2      https://m.media-amazon.com/images/I/61h78MEXoj...
# 3      https://m.media-amazon.com/images/I/61SUj2aKoE...
# 4      https://m.media-amazon.com/images/I/61bMNCeAUA...
# ...                                                  ...
# 42670  https://m.media-amazon.com/images/I/51KCB+egEs...
# 42671  https://m.media-amazon.com/images/I/51jV+o1LZE...
# 42672  https://m.media-amazon.com/images/I/71ySPkNLkG...
# 42673  https://m.media-amazon.com/images/I/411c0JFJ79...
# 42674  https://m.media-amazon.com/images/I/71wTn+zoSr...
#
#                                         product_page_url    data_collected_at  \
# 0      https://www.amazon.com/sspa/click?ie=UTF8&spc=...  2025-08-21 11:14:29
# 1      https://www.amazon.com/sspa/click?ie=UTF8&spc=...  2025-08-21 11:14:29
# 2      https://www.amazon.com/sspa/click?ie=UTF8&spc=...  2025-08-21 11:14:29
# 3      https://www.amazon.com/Apple-Cancellation-Tran...  2025-08-21 11:14:29
# 4      https://www.amazon.com/Apple-MX542LL-A-AirTag-...  2025-08-21 11:14:29
# ...                                                  ...                  ...
# 42670  https://www.amazon.com/Elgato-4K-Pro-Internal-...  2025-08-30 19:56:33
# 42671  https://www.amazon.com/Arlo-Essential-Spotligh...  2025-08-30 19:56:33
# 42672  https://www.amazon.com/GIGABYTE-FO32U2-32-3840...  2025-08-30 19:56:33
# 42673  https://www.amazon.com/Monoprice-XLR-Male-4-In...  2025-08-30 19:56:33
# 42674  https://www.amazon.com/Lorex-8-Channel-Securit...  2025-08-30 19:56:33
#
#         product_category
# 0                 Phones
# 1                Laptops
# 2                Laptops
# 3                 Phones
# 4                 Phones
# ...                  ...
# 42670       TV & Display
# 42671            Cameras
# 42672  Chargers & Cables
# 42673  Chargers & Cables
# 42674            Cameras
#
# [42675 rows x 11 columns]

# %%
num_df.isnull().sum()
# Out:
# product_rating           1024
# total_reviews            1024
# purchased_last_month    10511
# discounted_price         2062
# original_price           2062
# discount_percentage      2062
# dtype: int64

# %%
num_df['product_rating'].median()
# Out:
# 4.5

# %%
for column in num_df.columns:
    num_df[column] = num_df[column].fillna(num_df[column].median())

# %%
num_df.isnull().sum()
# Out:
# product_rating          0
# total_reviews           0
# purchased_last_month    0
# discounted_price        0
# original_price          0
# discount_percentage     0
# dtype: int64

# %%
for column in cat_df:
    mode_value=(cat_df[column].mode().values[0])
    cat_df[column]=cat_df[column].fillna(mode_value)

# %%
cat_df.isnull().sum()
# Out:
# product_title           0
# is_best_seller          0
# is_sponsored            0
# has_coupon              0
# buy_box_availability    0
# delivery_date           0
# sustainability_tags     0
# product_image_url       0
# product_page_url        0
# data_collected_at       0
# product_category        0
# dtype: int64

# %%
df = pd.concat([num_df, cat_df],axis = 1)
df.head()
# Out:
#    product_rating  total_reviews  purchased_last_month  discounted_price  \
# 0             4.6          375.0                 300.0             89.68
# 1             4.3         2457.0                6000.0              9.99
# 2             4.6         3044.0                2000.0            314.00
# 3             4.6        35882.0               10000.0            162.24
# 4             4.8        28988.0               10000.0             72.74
#
#    original_price  discount_percentage  \
# 0          159.00                43.60
# 1           15.99                37.52
# 2          349.00                10.03
# 3          162.24                 0.00
# 4           72.74                 0.00
#
#                                        product_title is_best_seller  \
# 0  BOYA BOYALINK 2 Wireless Lavalier Microphone f...       No Badge
# 1  LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...       No Badge
# 2  DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...       No Badge
# 3  Apple AirPods Pro 2 Wireless Earbuds, Active N...    Best Seller
# 4  Apple AirTag 4 Pack. Keep Track of and find Yo...       No Badge
#
#   is_sponsored             has_coupon buy_box_availability delivery_date  \
# 0    Sponsored  Save 15%  with coupon          Add to cart    2025-09-01
# 1    Sponsored              No Coupon          Add to cart    2025-08-29
# 2    Sponsored              No Coupon          Add to cart    2025-09-01
# 3      Organic              No Coupon          Add to cart    2025-09-04
# 4      Organic              No Coupon          Add to cart    2025-09-04
#
#   sustainability_tags                                  product_image_url  \
# 0       Carbon impact  https://m.media-amazon.com/images/I/71pAqiVEs3...
# 1      Small Business  https://m.media-amazon.com/images/I/61nbF6aVIP...
# 2      Small Business  https://m.media-amazon.com/images/I/61h78MEXoj...
# 3      Small Business  https://m.media-amazon.com/images/I/61SUj2aKoE...
# 4      Small Business  https://m.media-amazon.com/images/I/61bMNCeAUA...
#
#                                     product_page_url    data_collected_at  \
# 0  https://www.amazon.com/sspa/click?ie=UTF8&spc=...  2025-08-21 11:14:29
# 1  https://www.amazon.com/sspa/click?ie=UTF8&spc=...  2025-08-21 11:14:29
# 2  https://www.amazon.com/sspa/click?ie=UTF8&spc=...  2025-08-21 11:14:29
# 3  https://www.amazon.com/Apple-Cancellation-Tran...  2025-08-21 11:14:29
# 4  https://www.amazon.com/Apple-MX542LL-A-AirTag-...  2025-08-21 11:14:29
#
#   product_category
# 0           Phones
# 1          Laptops
# 2          Laptops
# 3           Phones
# 4           Phones

# %%
df.isnull().sum()
# Out:
# product_rating          0
# total_reviews           0
# purchased_last_month    0
# discounted_price        0
# original_price          0
# discount_percentage     0
# product_title           0
# is_best_seller          0
# is_sponsored            0
# has_coupon              0
# buy_box_availability    0
# delivery_date           0
# sustainability_tags     0
# product_image_url       0
# product_page_url        0
# data_collected_at       0
# product_category        0
# dtype: int64

# %%
df['total_reviews']= df['total_reviews'].astype(int)
df['purchased_last_month'] = df['purchased_last_month'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   product_rating        42675 non-null  float64
#  1   total_reviews         42675 non-null  int64
#  2   purchased_last_month  42675 non-null  int64
#  3   discounted_price      42675 non-null  float64
#  4   original_price        42675 non-null  float64
#  5   discount_percentage   42675 non-null  float64
#  6   product_title         42675 non-null  object
#  7   is_best_seller        42675 non-null  object
#  8   is_sponsored          42675 non-null  object
#  9   has_coupon            42675 non-null  object
#  10  buy_box_availability  42675 non-null  object
#  11  delivery_date         42675 non-null  object
#  12  sustainability_tags   42675 non-null  object
#  13  product_image_url     42675 non-null  object
#  14  product_page_url      42675 non-null  object
#  15  data_collected_at     42675 non-null  object
#  16  product_category      42675 non-null  object
# dtypes: float64(4), int64(2), object(11)
# memory usage: 5.5+ MB

# %%
df['delivery_date']=pd.to_datetime(df['delivery_date'],errors = 'coerce')
df['data_collected_at']=pd.to_datetime(df['data_collected_at'],errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   product_rating        42675 non-null  float64
#  1   total_reviews         42675 non-null  int64
#  2   purchased_last_month  42675 non-null  int64
#  3   discounted_price      42675 non-null  float64
#  4   original_price        42675 non-null  float64
#  5   discount_percentage   42675 non-null  float64
#  6   product_title         42675 non-null  object
#  7   is_best_seller        42675 non-null  object
#  8   is_sponsored          42675 non-null  object
#  9   has_coupon            42675 non-null  object
#  10  buy_box_availability  42675 non-null  object
#  11  delivery_date         42675 non-null  datetime64[ns]
#  12  sustainability_tags   42675 non-null  object
#  13  product_image_url     42675 non-null  object
#  14  product_page_url      42675 non-null  object
#  15  data_collected_at     42675 non-null  datetime64[ns]
#  16  product_category      42675 non-null  object
# dtypes: datetime64[ns](2), float64(4), int64(2), object(9)
# memory usage: 5.5+ MB

# %%
df.drop(['sustainability_tags'],axis = 1,inplace = True)

# %%
df.head(2)
# Out:
#    product_rating  total_reviews  purchased_last_month  discounted_price  \
# 0             4.6            375                   300             89.68
# 1             4.3           2457                  6000              9.99
#
#    original_price  discount_percentage  \
# 0          159.00                43.60
# 1           15.99                37.52
#
#                                        product_title is_best_seller  \
# 0  BOYA BOYALINK 2 Wireless Lavalier Microphone f...       No Badge
# 1  LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...       No Badge
#
#   is_sponsored             has_coupon buy_box_availability delivery_date  \
# 0    Sponsored  Save 15%  with coupon          Add to cart    2025-09-01
# 1    Sponsored              No Coupon          Add to cart    2025-08-29
#
#                                    product_image_url  \
# 0  https://m.media-amazon.com/images/I/71pAqiVEs3...
# 1  https://m.media-amazon.com/images/I/61nbF6aVIP...
#
#                                     product_page_url   data_collected_at  \
# 0  https://www.amazon.com/sspa/click?ie=UTF8&spc=... 2025-08-21 11:14:29
# 1  https://www.amazon.com/sspa/click?ie=UTF8&spc=... 2025-08-21 11:14:29
#
#   product_category  discounted_amount  estimated_revenue  percentage_band
# 0           Phones             115.40            26904.0             High
# 1          Laptops             -21.53            59940.0  Median discount

# %% [markdown]
# ### Feature Engineering

# %%
df['discounted_amount'] =df['original_price'] - df ['discount_percentage']

# %%
df ['estimated_revenue'] =df['discounted_price'] * df['purchased_last_month']

# %%
df['percentage_band']=pd.cut(x=df['discount_percentage'],
                            bins=[0, 10, 40, 70, 99],
                            labels=['Less discount','Median discount','High','very High'])

# %% [markdown]
# ### Univariate analysis

# %% [markdown]
# __categorical column analysis__

# %%
df['percentage_band'].value_counts()*100/len(df)
# Out:
# percentage_band
# Median discount    18.673697
# Less discount       7.163445
# High                2.685413
# very High           0.325718
# Name: count, dtype: float64

# %% [markdown]
# ### observation:

# %% [markdown]
# __Numirical column analysis__

# %%
df['total_reviews'].describe()
# Out:
# count     42675.000000
# mean       3021.260316
# std       12880.020115
# min           1.000000
# 25%          84.000000
# 50%         343.000000
# 75%        1825.500000
# max      865598.000000
# Name: total_reviews, dtype: float64

# %% [markdown]
# # Bi variate analysis

# %% [markdown]
# __cat vs num__

# %%
df[['product_category','purchased_last_month']].head()
# Out:
#   product_category  purchased_last_month
# 0           Phones                   300
# 1          Laptops                  6000
# 2          Laptops                  2000
# 3           Phones                 10000
# 4           Phones                 10000

# %%
df.groupby(['product_category'])['purchased_last_month'].sum().sort_values(ascending=False)
# Out:
# product_category
# Power & Batteries      26170250
# Other Electronics       4091800
# Phones                  3880950
# Laptops                 3828250
# Cameras                 1050900
# TV & Display             967150
# Chargers & Cables        879550
# Wearables                786850
# Storage                  628050
# Networking               321850
# Speakers                 301950
# Printers & Scanners      290450
# Headphones               230350
# Gaming                   152100
# Smart Home               131200
# Name: purchased_last_month, dtype: int64

# %%
df.groupby(['product_category'])['purchased_last_month'].sum().plot(kind='bar',figsize=(5,2))
plt.show()

# %% [markdown]
# ### Cat vs Cat

# %%
pd.crosstab(index = df['is_sponsored'],columns=df['product_category'])
# Out:
# product_category  Cameras  Chargers & Cables  Gaming  Headphones  Laptops  \
# is_sponsored
# Organic              3109               1573     797         798     8061
# Sponsored             568                260      12         199      632
#
# product_category  Networking  Other Electronics  Phones  Power & Batteries  \
# is_sponsored
# Organic                  837               8568    5190               1339
# Sponsored                233                187    1373               1538
#
# product_category  Printers & Scanners  Smart Home  Speakers  Storage  \
# is_sponsored
# Organic                           877         456      1119     1097
# Sponsored                           0           9       226      533
#
# product_category  TV & Display  Wearables
# is_sponsored
# Organic                   1407        436
# Sponsored                 1223         18

# %%
df.columns
# Out:
# Index(['product_rating', 'total_reviews', 'purchased_last_month',
#        'discounted_price', 'original_price', 'discount_percentage',
#        'product_title', 'is_best_seller', 'is_sponsored', 'has_coupon',
#        'buy_box_availability', 'delivery_date', 'product_image_url',
#        'product_page_url', 'data_collected_at', 'product_category',
#        'discounted_amount', 'estimated_revenue', 'percentage_band'],
#       dtype='object')

# %% [markdown]
# ### Num vs Num

# %%
df[['discounted_price','purchased_last_month']].corr()
# Out:
#                       discounted_price  purchased_last_month
# discounted_price              1.000000             -0.070198
# purchased_last_month         -0.070198              1.000000

# %% [markdown]
# ### Multi varition analysis

# %%
df[['product_category','product_rating','purchased_last_month']].head(2)
# Out:
#   product_category  product_rating  purchased_last_month
# 0           Phones             4.6                   300
# 1          Laptops             4.3                  6000

# %%
df['is_best_seller'].value_counts()
# Out:
# is_best_seller
# No Badge             40814
# Amazon's               744
# Limited time deal      409
# Best Seller            275
# Save 30%               125
# Ends in                 97
# Save 10%                61
# Save 18%                57
# Save 17%                51
# Save 12%                26
# Save 9%                 14
# Save 77%                 2
# Name: count, dtype: int64

# %%
pd.pivot_table(df,index=['product_category'],
               columns=['is_sponsored'],
               values=['purchased_last_month','total_reviews'],aggfunc='sum')
# Out:
#                     purchased_last_month             total_reviews
# is_sponsored                     Organic   Sponsored       Organic  Sponsored
# product_category
# Cameras                         873000.0    177900.0     3907413.0  1529043.0
# Chargers & Cables               830950.0     48600.0     7123839.0   200613.0
# Gaming                          149700.0      2400.0     4424329.0   287493.0
# Headphones                      206100.0     24250.0     5740934.0    25557.0
# Laptops                        3235100.0    593150.0    14774007.0  3179903.0
# Networking                      270750.0     51100.0     1393846.0   395332.0
# Other Electronics              3994500.0     97300.0    19107184.0   142605.0
# Phones                         2194750.0   1686200.0    20008935.0  9077692.0
# Power & Batteries              1562850.0  24607400.0    11764000.0  9050002.0
# Printers & Scanners             290450.0         NaN     1399794.0        NaN
# Smart Home                      129600.0      1600.0     1726532.0      268.0
# Speakers                        256950.0     45000.0     1375019.0    12296.0
# Storage                         461950.0    166100.0     5284733.0  1396865.0
# TV & Display                    641350.0    325800.0     3709262.0   819392.0
# Wearables                       256850.0    530000.0      661295.0   414101.0
